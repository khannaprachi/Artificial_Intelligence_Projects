# %% [markdown]
# <a href="https://colab.research.google.com/github/khannaprachi/Artificial_Intelligence_Projects/blob/main/IOTProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project
# #### Building IOT application for Smart City to enhance urban mobility by harnessing the power of IoT to make cities smarter and more livable. The system will utilize ML to classify traffic conditions and LSTMs for forecasting pickup trends.
#
# ## Models
# #### Model 1: Machine Learning – Classify the traffic conditions (e.g., light, moderate, heavy) in different zones of NYC using ML.
# #### Model 2: Time Series Prediction – Forecast the future demand for Uber pickups across NYC using LSTM.
#
# ## Dataset
# #### Dataset- Source of the dataset is NYC Taxi & Limousine Commission (TLC) - https://github.com/fivethirtyeight/uber-tlc-foil-response. It was obtained by FiveThirtyEight through a Freedom of Information Law request on July 20, 2015.

# %%
#import required libraries
import pandas as pd
import keras
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
from collections import Counter
from tensorflow import keras
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout, LSTM
from keras.layers import Activation
from keras.utils import pad_sequences
#from keras.wrappers.scikit_learn import KerasClassifier
#from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import GridSearchCV
# from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC   # The SVM Classifier from Scikit
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import time

# Setting seed for reproducibility
np.random.seed(1234)
PYTHONHASHSEED = 0

# %% [markdown]
# ## Load the Uber Data for the month of Jan-June 2015

# %%
from google.colab import drive
drive.mount('/content/drive')
path_uber_15='/content/drive/My Drive/ColabNotebooks/IOT/Final Project/uber-raw-data-janjune-15.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The dataset cosist for following columns -
# 1. Dispatching_base_num- The TLC base company code of the base that dispatched the Uber
# 2. Pickup_date- The date and time of the Uber pickup
# 3. Affiliated_base_num- The TLC base company code affiliated with the Uber pickup
# 4. locationID- The pickup location ID affiliated with the Uber pickup

# %%
df_uber = pd.read_csv(path_uber_15, delimiter = ",")
df_uber.head()
# Out:
#   Dispatching_base_num          Pickup_date Affiliated_base_num  locationID
# 0               B02617  2015-05-17 09:47:00              B02617         141
# 1               B02617  2015-05-17 09:47:00              B02617          65
# 2               B02617  2015-05-17 09:47:00              B02617         100
# 3               B02617  2015-05-17 09:47:00              B02774          80
# 4               B02617  2015-05-17 09:47:00              B02617          90

# %% [markdown]
# ## Data Pre-processing

# %%
df_uber['Pickup_date']= pd.to_datetime(df_uber['Pickup_date'])

# %%
df_uber.dtypes
# Out:
# Dispatching_base_num            object
# Pickup_date             datetime64[ns]
# Affiliated_base_num             object
# locationID                       int64
# dtype: object

# %%
#convert datetime to epoch/unix time
from datetime import datetime
df_uber['unix']=df_uber['Pickup_date'].astype(int) / 10**9

# %%
df_uber.head()
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-17 09:47:00              B02617         141
# 1               B02617 2015-05-17 09:47:00              B02617          65
# 2               B02617 2015-05-17 09:47:00              B02617         100
# 3               B02617 2015-05-17 09:47:00              B02774          80
# 4               B02617 2015-05-17 09:47:00              B02617          90
#
#            unix
# 0  1.431856e+09
# 1  1.431856e+09
# 2  1.431856e+09
# 3  1.431856e+09
# 4  1.431856e+09

# %%
#Shape of uber data
df_uber.shape
# Out:
# (14270479, 5)

# %% [markdown]
# #### Check missing values

# %%
#Check number of rows with missing values
missing_value=df_uber.isna().sum()
missing_val = missing_value[missing_value > 0]
for missing_count in missing_val.items():
  print(f"Count of missing values {missing_count}")
# Out:
# Count of missing values ('Affiliated_base_num', 162195)

# %%
#Plot missing values
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(4,3))
missing_value.plot.bar()
# Out:
# <Axes: >

# %%
#Remove rows with missing values
df_uber = df_uber.dropna()

# %%
missing_value=df_uber.isna().sum()
missing_val = missing_value[missing_value > 0]
for missing_count in missing_val.items():
  print(f"Count of missing values {missing_count}")
else:
  print("Data do not have any missing values")
# Out:
# Data do not have any missing values

# %%
#plot after removing missing values
f, ax = plt.subplots(figsize=(4,3))
missing_value.plot.bar()
# Out:
# <Axes: >

# %%
#Shape of data after removing missing values
df_uber.shape
# Out:
# (14108284, 5)

# %%
#Check duplicate rows in the dataset
duplicate_count=df_uber.duplicated().sum()
print(f"Count of duplicate data {duplicate_count}")
# Out:
# Count of duplicate data 896732

# %%
# Remove duplicate rows and check the sum of duplicate rows after removing duplicate rows
df_uber.drop_duplicates(inplace=True)
duplicate_count=df_uber.duplicated().sum()
print(f"Count of duplicate data after removing duplicate rows {duplicate_count}")
# Out:
# Count of duplicate data after removing duplicate rows 0

# %%
#Shape of data after removing duplicates
df_uber.shape
# Out:
# (13211552, 5)

# %% [markdown]
# ## Summary Data Pre-processing
# 1. Uber data for Jan-June month contain **162195** missing values in Affiliated_base_num column.
# 2. Data contain **896732** duplicate rows
# 3. After pre-processing i.e. removing missing values and duplicate data, final dataset consist of **13,211,552** rows

# %% [markdown]
# ## Perform Exploratory Data Analysis

# %%
#Derive month name, name of weekday, hour of the day, month and day numbers from Pickup_date in uber dataset
df_uber["month"] = df_uber["Pickup_date"].dt.month_name()
df_uber["weekday"] = df_uber["Pickup_date"].dt.day_name()
df_uber['hour'] = df_uber['Pickup_date'].dt.hour
df_uber['month_day'] = df_uber['Pickup_date'].apply(lambda pickup: pickup.strftime('%m-%d').split('-'))
df_uber['Monthumn'] = [month_day [0] for month_day in df_uber['month_day']]
df_uber['Day'] = [month_day [1] for month_day in df_uber['month_day']]

# %%
df_uber.head()
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-17 09:47:00              B02617         141
# 1               B02617 2015-05-17 09:47:00              B02617          65
# 2               B02617 2015-05-17 09:47:00              B02617         100
# 3               B02617 2015-05-17 09:47:00              B02774          80
# 4               B02617 2015-05-17 09:47:00              B02617          90
#
#            unix month weekday  hour month_day Monthumn Day
# 0  1.431856e+09   May  Sunday     9  [05, 17]       05  17
# 1  1.431856e+09   May  Sunday     9  [05, 17]       05  17
# 2  1.431856e+09   May  Sunday     9  [05, 17]       05  17
# 3  1.431856e+09   May  Sunday     9  [05, 17]       05  17
# 4  1.431856e+09   May  Sunday     9  [05, 17]       05  17

# %%
#Uber pickup count by month
df_uber["month"].value_counts()
# Out:
# June        2571771
# May         2483980
# February    2141306
# April       2112705
# March       2062639
# January     1839151
# Name: month, dtype: int64

# %%
#Plot monthly pickup count
import matplotlib.pyplot as plt

# Plot data
counts = df_uber["month"].value_counts()
plt.figure(figsize=(6, 4))
counts.plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Monthly Uber Pickups")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Highest pickups were performed in the month of **June**

# %%
#Count of monthly pickups per weekday
monthweek = pd.crosstab(index=df_uber["month"], columns=df_uber["weekday"])
monthweek
# Out:
# weekday   Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# month
# April     315002  238429    324545  273560    372522   250632     338015
# February  360136  264693    354962  284432    323955   276956     276172
# January   325261  182785    369693  219884    316857   188802     235869
# June      371225  375312    399377  334434    357782   405500     328141
# March     309631  269931    314785  313865    277026   320634     256767
# May       430134  255501    464298  390391    337607   290004     316045

# %%
#plot monthly pickups per weekday
plt.figure(figsize=(6, 4))
#monthweek.plot(kind="bar", figsize=(8, 6), cmap='coolwarm')
monthweek.plot(kind="bar", figsize=(8, 6))
plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Monthly pickups per weekday")
plt.xticks(rotation=0)

# Show the plot
plt.legend(title="Weekday", bbox_to_anchor=(1.05, 1), loc='upper left')  # Add legend
plt.show()

# %% [markdown]
# ## Summary of Weekday pickup analysis per month
# 1. Highest number of pickups are performed Saturday in May compared to all other months
# 2. January, February - Highest pickups are on Saturday
# 3. March - Hightest pickups are on Tuesday
# 4. April - Hightest pickups are on Thursday
# 5. May - Highest pickups are on Saturday
# 6. June - Hightest pickups are on Tuesday

# %%
#Hourly analysis
summary = df_uber.groupby(['weekday', 'hour'], as_index=False).size()
summary.head()
# Out:
#   weekday  hour   size
# 0  Friday     0  78936
# 1  Friday     1  44064
# 2  Friday     2  26942
# 3  Friday     3  18845
# 4  Friday     4  22798

# %%
#plot Uber hourly analysis by weekday
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.pointplot(x="hour", y="size", hue="weekday", data=summary, palette="Set1")
plt.xlabel("Hour of the Day")
plt.ylabel("Size")
plt.title("Hourly Uber pickups by Weekday")
plt.legend(title="Weekday")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summary of Hourly analysis by weekday
# 1. Friday and Saturday shows hightest numbers of pickups at 19 and 23 hour
# 2. Friday and Saturday shows upward trend in pickups after 21 hour vs Other days shows downward trend after 21 hour
# 3. Both Saturday and Sunday shows same trend between 0-14 hours however from 15 hours trend changes where Saturday has more number of pickups and pickup rise until 23 hours vs Sunday shows downward trend from 18 hour

# %%
#Unique location ids in uber data
unique_locid=df_uber['locationID'].unique()
len(unique_locid)
# Out:
# 262

# %%
#Mark the location ids by traffic contition base on number of pickups performed per location ids
for loc in unique_locid:
  df_temp=df_uber.loc[df_uber['locationID']==loc]
  if (len(df_temp) < 100000):
    df_uber.loc[df_uber['locationID'] == loc, 'Traffic_conditions']='light'
  elif (len(df_temp)>=100000 and len(df_temp) <=250000 ):
    df_uber.loc[df_uber['locationID'] == loc, 'Traffic_conditions']='moderate'
  elif (len(df_temp)>250000):
    df_uber.loc[df_uber['locationID'] == loc, 'Traffic_conditions']='heavy'

print(len(df_uber.loc[df_uber['Traffic_conditions']=='light']))
print(len(df_uber.loc[df_uber['Traffic_conditions']=='moderate']))
print(len(df_uber.loc[df_uber['Traffic_conditions']=='heavy']))
df_uber.head()
# Out:
# 3284638
# 6028415
# 3898499
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-17 09:47:00              B02617         141
# 1               B02617 2015-05-17 09:47:00              B02617          65
# 2               B02617 2015-05-17 09:47:00              B02617         100
# 3               B02617 2015-05-17 09:47:00              B02774          80
# 4               B02617 2015-05-17 09:47:00              B02617          90
#
#            unix month weekday  hour month_day Monthumn Day Traffic_conditions
# 0  1.431856e+09   May  Sunday     9  [05, 17]       05  17           moderate
# 1  1.431856e+09   May  Sunday     9  [05, 17]       05  17              light
# 2  1.431856e+09   May  Sunday     9  [05, 17]       05  17           moderate
# 3  1.431856e+09   May  Sunday     9  [05, 17]       05  17           moderate
# 4  1.431856e+09   May  Sunday     9  [05, 17]       05  17           moderate

# %%
df_uber.loc[(df_uber['Traffic_conditions']!='light') & (df_uber['Traffic_conditions']!='moderate') & (df_uber['Traffic_conditions']!='heavy' )]
# Out:
# Empty DataFrame
# Columns: [Dispatching_base_num, Pickup_date, Affiliated_base_num, locationID, unix, month, weekday, hour, month_day, Monthumn, Day, Traffic_conditions]
# Index: []

# %%
df_uber.to_csv('/content/drive/My Drive/ColabNotebooks/IOT/Final Project/uber-raw-data-janjune-15_trafficcond.csv', index = None)

# %% [markdown]
# ## **Model 1 - Classify the traffic conditions (e.g., light, moderate, heavy) in different zones of NYC using Machine Learning Model**

# %%
#Sample dataset to be used for ML model training
random_sample = df_uber.sample(frac=0.01, random_state=42)
random_sample.head()
# Out:
#          Dispatching_base_num         Pickup_date Affiliated_base_num  \
# 8799280                B02764 2015-02-04 17:48:48              B02764
# 7479949                B02764 2015-04-19 05:34:00              B02764
# 8955397                B02764 2015-06-25 13:05:00              B02670
# 8303321                B02682 2015-05-02 18:17:00              B02682
# 13462605               B02765 2015-06-17 18:51:00              B02765
#
#           locationID          unix     month    weekday  hour month_day  \
# 8799280          219  1.423072e+09  February  Wednesday    17  [02, 04]
# 7479949          262  1.429422e+09     April     Sunday     5  [04, 19]
# 8955397          140  1.435238e+09      June   Thursday    13  [06, 25]
# 8303321          112  1.430591e+09       May   Saturday    18  [05, 02]
# 13462605          90  1.434567e+09      June  Wednesday    18  [06, 17]
#
#          Monthumn Day Traffic_conditions
# 8799280        02  04              light
# 7479949        04  19           moderate
# 8955397        06  25           moderate
# 8303321        05  02           moderate
# 13462605       06  17           moderate

# %%
light_cond=len(random_sample.loc[random_sample['Traffic_conditions']=='light'])
moderate_cond=len(random_sample.loc[random_sample['Traffic_conditions']=='moderate'])
heavy_cond=len(random_sample.loc[random_sample['Traffic_conditions']=='heavy'])
print(f"Sample data contain {light_cond} location ids with light traffic condition")
print(f"Sample data contain {moderate_cond} location ids with moderate traffic condition")
print(f"Sample data contain {heavy_cond} location ids with heavy traffic condition")
# Out:
# Sample data contain 32901 location ids with light traffic condition
# Sample data contain 60403 location ids with moderate traffic condition
# Sample data contain 38812 location ids with heavy traffic condition

# %%
random_sample.shape
# Out:
# (132116, 12)

# %% [markdown]
# ### Pre-processing data for DecisionTreeClassifier Model

# %%
# MinMaxscaling and LabelEncoding of data

X = random_sample[['unix','locationID']]
scaler = MinMaxScaler()
X_new = scaler.fit_transform(X)
y = random_sample['Traffic_conditions']
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)
X_train, X_test, Y_train, Y_test = train_test_split(X_new, y, test_size = 0.2, random_state = 323)

# %% [markdown]
# ### Train DecisionTreeClassifier Model

# %%
#Apply DecisionTreeClassifier ML model

classifier = DecisionTreeClassifier(max_depth=10)
classifier.fit(X_train, Y_train)
#Predicting the Test Set
Y_pred = classifier.predict(X_test)

# %% [markdown]
# ### Model Predictions

# %%
# print the accuracy
print("Accuracy of Decision Tree Classifier: ",
      accuracy_score(Y_test, Y_pred))
# print other performance metrics
print("Precision of Decision Tree Classifier: ",
      precision_score(Y_test, Y_pred, average='weighted'))
print("Recall of Decision Tree Classifier: ",
      recall_score(Y_test, Y_pred, average='weighted'))
print("F1-Score of Decision Tree Classifier: ",
      f1_score(Y_test, Y_pred, average='weighted'))
# Out:
# Accuracy of Decision Tree Classifier:  0.9955343627005753
# Precision of Decision Tree Classifier:  0.9955778867115881
# Recall of Decision Tree Classifier:  0.9955343627005753
# F1-Score of Decision Tree Classifier:  0.995525418264997

# %% [markdown]
# ### Plot Model Predictions

# %%
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm,annot=True,fmt='2.0f')
# Out:
# <Axes: >

# %%
# Show predicted vs actual values for Traffic Condition for first 100 results
fig, ax = plt.subplots(figsize=(10,5))
fig.suptitle('Preiction of Traffic Condition on Location ids', fontsize=22, fontweight='bold')
#ax.set_title('mu = %g, ph=%g ' %(mu, ph))
ax.plot( Y_pred[0:100], label='Predicted Value ', linewidth=3, color='orange', alpha=0.6)
ax.plot(Y_test[0:100], label='Traffic Cond',linewidth=1, color='blue')
ax.set( yticks=np.arange(Y_pred.min(), Y_pred.max(), 1), yticklabels=range(0, 2));
ax.set_xlabel('Number of pickups')
ax.set_ylabel('Traffic Condition')
ax.legend(loc='upper right',  bbox_to_anchor=(0.98, 0.98))

# %%
# scatter plot
plt.figure(figsize=(6, 5))
plt.scatter(Y_test, Y_pred, color='blue')
plt.xlabel('Actual Traffic Conditions')
plt.ylabel('Predicted Traffic Conditions')
plt.title('Predicted vs. Actual Traffic Conditions')
plt.grid(True)
plt.legend(['Catagories'], loc='upper right',  bbox_to_anchor=(0.98, 0.88))
plt.show()

# %% [markdown]
# ## DecisionTreeClassifier Result Analysis
# - Model is accurately predicting Traffic conditions light, moderate and heavy based on the input features location ids and unix date time
# - Accuracy of Decision Tree Classifier:  0.9955343627005753
# - Precision of Decision Tree Classifier:  0.9955778867115881
# - Recall of Decision Tree Classifier:  0.9955343627005753
# - F1-Score of Decision Tree Classifier:  0.995525418264997

# %%
#Save ML model predictions
df_ml_predict=pd.DataFrame()
df_ml_predict['Traffic_Condition_Actual']=Y_test
df_ml_predict['Traffic_Condition_Predicted']=Y_pred
df_ml_predict.to_csv('/content/drive/My Drive/ColabNotebooks/IOT/Final Project/Final_Project_ML_Prediction.csv', index = None)

# %% [markdown]
# ## **Model 2 - Time Series Prediction – Forecast the future demand for Uber pickups across NYC using LSTM**

# %%
month_day_group = df_uber.groupby(by = ['Monthumn', 'Day']).size().unstack()
month_day_group
# Out:
# Day            01       02       03       04       05       06       07  \
# Monthumn
# 01        54369.0  37789.0  56440.0  39362.0  41045.0  50428.0  59771.0
# 02        73855.0  66435.0  67531.0  64330.0  77814.0  82677.0  78290.0
# 03        65013.0  53372.0  67373.0  65268.0  69742.0  74966.0  74097.0
# 04        64412.0  68539.0  71292.0  65223.0  55686.0  51019.0  62838.0
# 05        85097.0  95693.0  74748.0  61799.0  70715.0  74536.0  79739.0
# 06        85030.0  87861.0  79747.0  85836.0  93082.0  93713.0  82361.0
#
# Day            08       09       10  ...       22       23       24       25  \
# Monthumn                             ...
# 01        68634.0  67709.0  75676.0  ...  63139.0  69251.0  77850.0  55737.0
# 02        60590.0  59971.0  62595.0  ...  63870.0  68709.0  76462.0  72202.0
# 03        56893.0  50523.0  64741.0  ...  63765.0  56395.0  59494.0  67387.0
# 04        66425.0  71239.0  75417.0  ...  74769.0  83122.0  90534.0  96260.0
# 05        83794.0  90412.0  74822.0  ...  80253.0  73776.0  64869.0  56636.0
# 06        71611.0  76059.0  80039.0  ...  70212.0  84311.0  83254.0  90266.0
#
# Day            26        27       28       29       30       31
# Monthumn
# 01        41921.0   24422.0  58188.0  66429.0  80565.0  88907.0
# 02        80585.0   85703.0  85069.0      NaN      NaN      NaN
# 03        71295.0   77449.0  83857.0  69077.0  58436.0  71292.0
# 04        81836.0   61267.0  64323.0  70306.0  77116.0      NaN
# 05        68003.0   80519.0  86293.0  89904.0  95821.0  89357.0
# 06        91319.0  119208.0  85442.0  69605.0  76246.0      NaN
#
# [6 rows x 31 columns]

# %%
## Aggregate results to form a time-series
month_day_series = [month_day_group.iloc[r,:] for r in range(month_day_group.shape[0])]

# %%
month_day_list=[]
for month in month_day_series:
  for days in month:
    month_day_list.append(days)

print(f"Length of MonthDay time-series {len(month_day_list)}")
# Out:
# Length of MonthDay time-series 186

# %%
## When month is shorter than 31 days, there will be missing values in series. Removing missing values from series.
nan_indx=np.argwhere(np.isnan(month_day_list) == True)
print(f"number of missing values {len(nan_indx)}")
remove_inds = list(nan_indx.reshape((1,len(nan_indx)))[0])
print(f"ids tha are removed {remove_inds}")
month_day_list_nonan = [month_day_list[i] for i,j in enumerate(month_day_list) if i not in remove_inds]
print(f"Final Length of Monthday list {len(month_day_list_nonan)}")
# Out:
# number of missing values 5
# ids tha are removed [59, 60, 61, 123, 185]
# Final Length of Monthday list 181

# %%
## Convert time-series into data-frame
df_uber_final = pd.DataFrame({'Days': range(1,len(month_day_list_nonan)+1), 'UberPickups': month_day_list_nonan})
df_uber_final.head()
# Out:
#    Days  UberPickups
# 0     1      54369.0
# 1     2      37789.0
# 2     3      56440.0
# 3     4      39362.0
# 4     5      41045.0

# %% [markdown]
# ### Pre-processing data for LSTM
# #### Use last 2 weeks(14 days) to predict Uber Trips for current day

# %%
#Apply MinMax scalling to transforms data by scaling features to a given range (0,1)

## Split into train-test set:
train_uber_series = df_uber_final.iloc[0:167,1:2].values
test_uber_series = df_uber_final.iloc[167:,1:2].values

print ('Training data: ', train_uber_series.shape)
print ('Testing data: ', test_uber_series.shape)

## Feature-scaling:
mms = MinMaxScaler(feature_range = (0,1))
train_uber_series_scaled = mms.fit_transform(train_uber_series)
# Out:
# Training data:  (167, 1)
# Testing data:  (14, 1)

# %%
x_train = []
y_train = []

for rides in range(14, train_uber_series.shape[0]):
    x_train.append(train_uber_series_scaled[rides-14:rides,0])
    y_train.append(train_uber_series_scaled[rides,0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, newshape = (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# ### Training LSTM Model

# %%
np.random.seed(11)
t_start = time.time()

def build_rnn(num_units, input_x, input_y, drpout, epochs, size_of_batch, optimizer, loss):

    lstmmodel = Sequential()

    ## Adding first LSTM layer:
    lstmmodel.add(LSTM(units = num_units, return_sequences = True, input_shape = (input_x.shape[1],1)))
    lstmmodel.add(Dropout(drpout))

    ## Adding second LSTM layer:
    lstmmodel.add(LSTM(units = num_units, return_sequences = True))
    lstmmodel.add(Dropout(drpout))

    ## Adding third LSTM layer:
    lstmmodel.add(LSTM(units = num_units, return_sequences = True))
    lstmmodel.add(Dropout(drpout))

    ## Adding fourth LSTM layer:
    lstmmodel.add(LSTM(units = num_units, return_sequences = True))
    lstmmodel.add(Dropout(drpout))

    ## Adding fifth LSTM layer:
    lstmmodel.add(LSTM(units = num_units, return_sequences = False))
    lstmmodel.add(Dropout(drpout))

    ## Adding o/p layer:
    lstmmodel.add(Dense(units = 1))

    ## Compiling RNN:
    lstmmodel.compile(optimizer = optimizer, loss = loss)

    ## Fitting RNN to training set:
    lstmmodel.fit(x = input_x, y = input_y, epochs = epochs, batch_size = size_of_batch)

    return lstmmodel

lstmmodel = build_rnn(num_units = 40, input_x = x_train, input_y = y_train, drpout = 0.2, epochs = 1000, size_of_batch = 16, optimizer = 'adam', loss = 'mean_squared_error')

print (time.time() - t_start)
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 7s 21ms/step - loss: 0.2300
# Epoch 2/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0351
# Epoch 3/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0290
# Epoch 4/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0272
# Epoch 5/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0257
# Epoch 6/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0235
# Epoch 7/1000
# 10/10 [==============================] - 0s 34ms/step - loss: 0.0247
# Epoch 8/1000
# 10/10 [==============================] - 0s 33ms/step - loss: 0.0243
# Epoch 9/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0283
# Epoch 10/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0249
# Epoch 11/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0254
# Epoch 12/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0295
# Epoch 13/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0246
# Epoch 14/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0221
# Epoch 15/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0256
# Epoch 16/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0217
# Epoch 17/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0228
# Epoch 18/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0238
# Epoch 19/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0237
# Epoch 20/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0205
# Epoch 21/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0219
# Epoch 22/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0248
# Epoch 23/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0209
# Epoch 24/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0238
# Epoch 25/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0250
# Epoch 26/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0265
# Epoch 27/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0229
# Epoch 28/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0257
# Epoch 29/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0262
# Epoch 30/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0269
# Epoch 31/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0226
# Epoch 32/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0207
# Epoch 33/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0233
# Epoch 34/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0238
# Epoch 35/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0231
# Epoch 36/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0235
# Epoch 37/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0230
# Epoch 38/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0247
# Epoch 39/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0237
# Epoch 40/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0265
# Epoch 41/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0247
# Epoch 42/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0244
# Epoch 43/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0194
# Epoch 44/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0236
# Epoch 45/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0224
# Epoch 46/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0230
# Epoch 47/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0201
# Epoch 48/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0255
# Epoch 49/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0219
# Epoch 50/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0243
# Epoch 51/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0236
# Epoch 52/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0207
# Epoch 53/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0210
# Epoch 54/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0206
# Epoch 55/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0221
# Epoch 56/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0213
# Epoch 57/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0219
# Epoch 58/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0219
# Epoch 59/1000
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0233
# Epoch 60/1000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0219
# Epoch 61/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0235
# Epoch 62/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0220
# Epoch 63/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0233
# Epoch 64/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0219
# Epoch 65/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0232
# Epoch 66/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0213
# Epoch 67/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0241
# Epoch 68/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0211
# Epoch 69/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0213
# Epoch 70/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0219
# Epoch 71/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0230
# Epoch 72/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0219
# Epoch 73/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0221
# Epoch 74/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0213
# Epoch 75/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0243
# Epoch 76/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0207
# Epoch 77/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0197
# Epoch 78/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0209
# Epoch 79/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0216
# Epoch 80/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0205
# Epoch 81/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0215
# Epoch 82/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0207
# Epoch 83/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0200
# Epoch 84/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0202
# Epoch 85/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0187
# Epoch 86/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0199
# Epoch 87/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0217
# Epoch 88/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0240
# Epoch 89/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0212
# Epoch 90/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0202
# Epoch 91/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0208
# Epoch 92/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0223
# Epoch 93/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0212
# Epoch 94/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0220
# Epoch 95/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0208
# Epoch 96/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0218
# Epoch 97/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0218
# Epoch 98/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0211
# Epoch 99/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0210
# Epoch 100/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0190
# Epoch 101/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0200
# Epoch 102/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0196
# Epoch 103/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0228
# Epoch 104/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0222
# Epoch 105/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0189
# Epoch 106/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0188
# Epoch 107/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0202
# Epoch 108/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0203
# Epoch 109/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0184
# Epoch 110/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0190
# Epoch 111/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0207
# Epoch 112/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0207
# Epoch 113/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0199
# Epoch 114/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0193
# Epoch 115/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0177
# Epoch 116/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0181
# Epoch 117/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0188
# Epoch 118/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0201
# Epoch 119/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0185
# Epoch 120/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0192
# Epoch 121/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0175
# Epoch 122/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0188
# Epoch 123/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0197
# Epoch 124/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0196
# Epoch 125/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0187
# Epoch 126/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0196
# Epoch 127/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0187
# Epoch 128/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0186
# Epoch 129/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0210
# Epoch 130/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0199
# Epoch 131/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0181
# Epoch 132/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0192
# Epoch 133/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0216
# Epoch 134/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0208
# Epoch 135/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0186
# Epoch 136/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0182
# Epoch 137/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0185
# Epoch 138/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0193
# Epoch 139/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0183
# Epoch 140/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0206
# Epoch 141/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0214
# Epoch 142/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0173
# Epoch 143/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0200
# Epoch 144/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0230
# Epoch 145/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0163
# Epoch 146/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0179
# Epoch 147/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0212
# Epoch 148/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0194
# Epoch 149/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0170
# Epoch 150/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0178
# Epoch 151/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0187
# Epoch 152/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0176
# Epoch 153/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0181
# Epoch 154/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0191
# Epoch 155/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0176
# Epoch 156/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0173
# Epoch 157/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0159
# Epoch 158/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0168
# Epoch 159/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0188
# Epoch 160/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0163
# Epoch 161/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0184
# Epoch 162/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0187
# Epoch 163/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0157
# Epoch 164/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0169
# Epoch 165/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0154
# Epoch 166/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0155
# Epoch 167/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0161
# Epoch 168/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0185
# Epoch 169/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0166
# Epoch 170/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0157
# Epoch 171/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0164
# Epoch 172/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0164
# Epoch 173/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0178
# Epoch 174/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0167
# Epoch 175/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0155
# Epoch 176/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0154
# Epoch 177/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0155
# Epoch 178/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0186
# Epoch 179/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0160
# Epoch 180/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0189
# Epoch 181/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0167
# Epoch 182/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0161
# Epoch 183/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0152
# Epoch 184/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0165
# Epoch 185/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0156
# Epoch 186/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0146
# Epoch 187/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0169
# Epoch 188/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0171
# Epoch 189/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0167
# Epoch 190/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0145
# Epoch 191/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0165
# Epoch 192/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0156
# Epoch 193/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0161
# Epoch 194/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0154
# Epoch 195/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0136
# Epoch 196/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0147
# Epoch 197/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0154
# Epoch 198/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0137
# Epoch 199/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0145
# Epoch 200/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0146
# Epoch 201/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0161
# Epoch 202/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0132
# Epoch 203/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0129
# Epoch 204/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0154
# Epoch 205/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0141
# Epoch 206/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0133
# Epoch 207/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0143
# Epoch 208/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0144
# Epoch 209/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0193
# Epoch 210/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0148
# Epoch 211/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0152
# Epoch 212/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0152
# Epoch 213/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0138
# Epoch 214/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0138
# Epoch 215/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0141
# Epoch 216/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0136
# Epoch 217/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0146
# Epoch 218/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0157
# Epoch 219/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0150
# Epoch 220/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0166
# Epoch 221/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0141
# Epoch 222/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0147
# Epoch 223/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0138
# Epoch 224/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0140
# Epoch 225/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0130
# Epoch 226/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0133
# Epoch 227/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0132
# Epoch 228/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0138
# Epoch 229/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0151
# Epoch 230/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0130
# Epoch 231/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0138
# Epoch 232/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0120
# Epoch 233/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0125
# Epoch 234/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0140
# Epoch 235/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0139
# Epoch 236/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0143
# Epoch 237/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0128
# Epoch 238/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0137
# Epoch 239/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0123
# Epoch 240/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0145
# Epoch 241/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0151
# Epoch 242/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0152
# Epoch 243/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0168
# Epoch 244/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0131
# Epoch 245/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0133
# Epoch 246/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0144
# Epoch 247/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0130
# Epoch 248/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0162
# Epoch 249/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0132
# Epoch 250/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0131
# Epoch 251/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0134
# Epoch 252/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0134
# Epoch 253/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0138
# Epoch 254/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0146
# Epoch 255/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0126
# Epoch 256/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0137
# Epoch 257/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0125
# Epoch 258/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0134
# Epoch 259/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0140
# Epoch 260/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0133
# Epoch 261/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0124
# Epoch 262/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0141
# Epoch 263/1000
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0142
# Epoch 264/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0122
# Epoch 265/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0126
# Epoch 266/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0132
# Epoch 267/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0123
# Epoch 268/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0130
# Epoch 269/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0136
# Epoch 270/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0140
# Epoch 271/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0146
# Epoch 272/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0143
# Epoch 273/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0127
# Epoch 274/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0128
# Epoch 275/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0131
# Epoch 276/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0115
# Epoch 277/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0120
# Epoch 278/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0122
# Epoch 279/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0125
# Epoch 280/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0135
# Epoch 281/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0131
# Epoch 282/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0127
# Epoch 283/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0135
# Epoch 284/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0119
# Epoch 285/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0127
# Epoch 286/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0128
# Epoch 287/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0142
# Epoch 288/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0134
# Epoch 289/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0141
# Epoch 290/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0124
# Epoch 291/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0124
# Epoch 292/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0138
# Epoch 293/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0120
# Epoch 294/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0135
# Epoch 295/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0138
# Epoch 296/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0126
# Epoch 297/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0118
# Epoch 298/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0116
# Epoch 299/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0121
# Epoch 300/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0123
# Epoch 301/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0118
# Epoch 302/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0118
# Epoch 303/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0126
# Epoch 304/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0125
# Epoch 305/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0136
# Epoch 306/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0131
# Epoch 307/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0139
# Epoch 308/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0147
# Epoch 309/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0133
# Epoch 310/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0126
# Epoch 311/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0129
# Epoch 312/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0119
# Epoch 313/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0128
# Epoch 314/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0129
# Epoch 315/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0112
# Epoch 316/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0123
# Epoch 317/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0106
# Epoch 318/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0120
# Epoch 319/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0123
# Epoch 320/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0136
# Epoch 321/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0113
# Epoch 322/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0125
# Epoch 323/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0115
# Epoch 324/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0140
# Epoch 325/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0135
# Epoch 326/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0109
# Epoch 327/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0128
# Epoch 328/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0113
# Epoch 329/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0109
# Epoch 330/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0127
# Epoch 331/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0124
# Epoch 332/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0117
# Epoch 333/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0118
# Epoch 334/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0106
# Epoch 335/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0123
# Epoch 336/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0124
# Epoch 337/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0124
# Epoch 338/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0120
# Epoch 339/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0128
# Epoch 340/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0117
# Epoch 341/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0116
# Epoch 342/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0119
# Epoch 343/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0135
# Epoch 344/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0118
# Epoch 345/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0125
# Epoch 346/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0113
# Epoch 347/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0119
# Epoch 348/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0128
# Epoch 349/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0112
# Epoch 350/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0106
# Epoch 351/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0120
# Epoch 352/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0111
# Epoch 353/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0107
# Epoch 354/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0103
# Epoch 355/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0108
# Epoch 356/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0112
# Epoch 357/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0132
# Epoch 358/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0121
# Epoch 359/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0116
# Epoch 360/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0132
# Epoch 361/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0139
# Epoch 362/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0115
# Epoch 363/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0111
# Epoch 364/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0115
# Epoch 365/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0116
# Epoch 366/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0132
# Epoch 367/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0129
# Epoch 368/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0121
# Epoch 369/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0111
# Epoch 370/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0127
# Epoch 371/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0117
# Epoch 372/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0115
# Epoch 373/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0120
# Epoch 374/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0105
# Epoch 375/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0103
# Epoch 376/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0113
# Epoch 377/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0130
# Epoch 378/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0120
# Epoch 379/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0109
# Epoch 380/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0111
# Epoch 381/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0107
# Epoch 382/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0106
# Epoch 383/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0104
# Epoch 384/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0103
# Epoch 385/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0112
# Epoch 386/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0110
# Epoch 387/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0110
# Epoch 388/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0100
# Epoch 389/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0116
# Epoch 390/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0117
# Epoch 391/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0113
# Epoch 392/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0120
# Epoch 393/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0113
# Epoch 394/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0099
# Epoch 395/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0117
# Epoch 396/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0113
# Epoch 397/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0114
# Epoch 398/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0100
# Epoch 399/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0120
# Epoch 400/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0111
# Epoch 401/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0124
# Epoch 402/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0113
# Epoch 403/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0116
# Epoch 404/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0103
# Epoch 405/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0109
# Epoch 406/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0120
# Epoch 407/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0112
# Epoch 408/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0109
# Epoch 409/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0119
# Epoch 410/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0110
# Epoch 411/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0114
# Epoch 412/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0114
# Epoch 413/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0103
# Epoch 414/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0125
# Epoch 415/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0107
# Epoch 416/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0112
# Epoch 417/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0103
# Epoch 418/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0102
# Epoch 419/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0105
# Epoch 420/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0109
# Epoch 421/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0111
# Epoch 422/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0100
# Epoch 423/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0114
# Epoch 424/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0113
# Epoch 425/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0113
# Epoch 426/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0116
# Epoch 427/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0112
# Epoch 428/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0110
# Epoch 429/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0115
# Epoch 430/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0100
# Epoch 431/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0114
# Epoch 432/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0116
# Epoch 433/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0116
# Epoch 434/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0116
# Epoch 435/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0101
# Epoch 436/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0091
# Epoch 437/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0105
# Epoch 438/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0110
# Epoch 439/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0098
# Epoch 440/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0104
# Epoch 441/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0115
# Epoch 442/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0109
# Epoch 443/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0116
# Epoch 444/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0093
# Epoch 445/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0100
# Epoch 446/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0103
# Epoch 447/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0096
# Epoch 448/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0121
# Epoch 449/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0104
# Epoch 450/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0100
# Epoch 451/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0093
# Epoch 452/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0101
# Epoch 453/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0102
# Epoch 454/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0099
# Epoch 455/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0116
# Epoch 456/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0107
# Epoch 457/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0119
# Epoch 458/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0100
# Epoch 459/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0099
# Epoch 460/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0109
# Epoch 461/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0098
# Epoch 462/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0098
# Epoch 463/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0103
# Epoch 464/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0099
# Epoch 465/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0095
# Epoch 466/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0103
# Epoch 467/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0106
# Epoch 468/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0101
# Epoch 469/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0112
# Epoch 470/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0098
# Epoch 471/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0090
# Epoch 472/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0084
# Epoch 473/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0099
# Epoch 474/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0100
# Epoch 475/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0097
# Epoch 476/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0097
# Epoch 477/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0097
# Epoch 478/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0117
# Epoch 479/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0098
# Epoch 480/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0093
# Epoch 481/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0099
# Epoch 482/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0097
# Epoch 483/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0135
# Epoch 484/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0112
# Epoch 485/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0110
# Epoch 486/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0105
# Epoch 487/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0107
# Epoch 488/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0099
# Epoch 489/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0111
# Epoch 490/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0105
# Epoch 491/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0093
# Epoch 492/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0092
# Epoch 493/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0092
# Epoch 494/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0095
# Epoch 495/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0090
# Epoch 496/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0097
# Epoch 497/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0087
# Epoch 498/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0093
# Epoch 499/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0092
# Epoch 500/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0093
# Epoch 501/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0099
# Epoch 502/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0087
# Epoch 503/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0097
# Epoch 504/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0084
# Epoch 505/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0088
# Epoch 506/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0077
# Epoch 507/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0103
# Epoch 508/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0105
# Epoch 509/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0099
# Epoch 510/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0089
# Epoch 511/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0087
# Epoch 512/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0095
# Epoch 513/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0087
# Epoch 514/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0094
# Epoch 515/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0080
# Epoch 516/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0079
# Epoch 517/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0091
# Epoch 518/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0083
# Epoch 519/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0108
# Epoch 520/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0099
# Epoch 521/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0089
# Epoch 522/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0089
# Epoch 523/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0102
# Epoch 524/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0091
# Epoch 525/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0095
# Epoch 526/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0078
# Epoch 527/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0081
# Epoch 528/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0092
# Epoch 529/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0086
# Epoch 530/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0083
# Epoch 531/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0083
# Epoch 532/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0092
# Epoch 533/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0085
# Epoch 534/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0088
# Epoch 535/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0090
# Epoch 536/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0082
# Epoch 537/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0091
# Epoch 538/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0096
# Epoch 539/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0085
# Epoch 540/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0090
# Epoch 541/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0093
# Epoch 542/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0084
# Epoch 543/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0089
# Epoch 544/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0091
# Epoch 545/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0079
# Epoch 546/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0084
# Epoch 547/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0115
# Epoch 548/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0107
# Epoch 549/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0105
# Epoch 550/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0082
# Epoch 551/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0077
# Epoch 552/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0084
# Epoch 553/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0090
# Epoch 554/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0097
# Epoch 555/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0087
# Epoch 556/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0078
# Epoch 557/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0079
# Epoch 558/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0097
# Epoch 559/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0092
# Epoch 560/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0088
# Epoch 561/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0083
# Epoch 562/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0086
# Epoch 563/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0091
# Epoch 564/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0081
# Epoch 565/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0087
# Epoch 566/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0077
# Epoch 567/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0090
# Epoch 568/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0081
# Epoch 569/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0085
# Epoch 570/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0099
# Epoch 571/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0085
# Epoch 572/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0079
# Epoch 573/1000
# ...
# Epoch 811/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0054
# Epoch 812/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0053
# Epoch 813/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0052
# Epoch 814/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0042
# Epoch 815/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0048
# Epoch 816/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0049
# Epoch 817/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0035
# Epoch 818/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0046
# Epoch 819/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0046
# Epoch 820/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0048
# Epoch 821/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 822/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0059
# Epoch 823/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0054
# Epoch 824/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0068
# Epoch 825/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0043
# Epoch 826/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0049
# Epoch 827/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 828/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0047
# Epoch 829/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0091
# Epoch 830/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0071
# Epoch 831/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0077
# Epoch 832/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0070
# Epoch 833/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0051
# Epoch 834/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0046
# Epoch 835/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0037
# Epoch 836/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0036
# Epoch 837/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0043
# Epoch 838/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0047
# Epoch 839/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0041
# Epoch 840/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0032
# Epoch 841/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0036
# Epoch 842/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0038
# Epoch 843/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0041
# Epoch 844/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0034
# Epoch 845/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0053
# Epoch 846/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0037
# Epoch 847/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0038
# Epoch 848/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0047
# Epoch 849/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0042
# Epoch 850/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0033
# Epoch 851/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0045
# Epoch 852/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0038
# Epoch 853/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0039
# Epoch 854/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0039
# Epoch 855/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0037
# Epoch 856/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0033
# Epoch 857/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0033
# Epoch 858/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0038
# Epoch 859/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0046
# Epoch 860/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0042
# Epoch 861/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0038
# Epoch 862/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0035
# Epoch 863/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0047
# Epoch 864/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0060
# Epoch 865/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0042
# Epoch 866/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0040
# Epoch 867/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0039
# Epoch 868/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0049
# Epoch 869/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0055
# Epoch 870/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0043
# Epoch 871/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0043
# Epoch 872/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0039
# Epoch 873/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0046
# Epoch 874/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0044
# Epoch 875/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0053
# Epoch 876/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0045
# Epoch 877/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0044
# Epoch 878/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0036
# Epoch 879/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0029
# Epoch 880/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0034
# Epoch 881/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0036
# Epoch 882/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0040
# Epoch 883/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0038
# Epoch 884/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0033
# Epoch 885/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0041
# Epoch 886/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0033
# Epoch 887/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0048
# Epoch 888/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0043
# Epoch 889/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0041
# Epoch 890/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0044
# Epoch 891/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0031
# Epoch 892/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0041
# Epoch 893/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 894/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0060
# Epoch 895/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0052
# Epoch 896/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0046
# Epoch 897/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0040
# Epoch 898/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0038
# Epoch 899/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0041
# Epoch 900/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0037
# Epoch 901/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0035
# Epoch 902/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0032
# Epoch 903/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0027
# Epoch 904/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0032
# Epoch 905/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0031
# Epoch 906/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0034
# Epoch 907/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0036
# Epoch 908/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0027
# Epoch 909/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0029
# Epoch 910/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0032
# Epoch 911/1000
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0032
# Epoch 912/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0034
# Epoch 913/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 914/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0032
# Epoch 915/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0031
# Epoch 916/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0031
# Epoch 917/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0034
# Epoch 918/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0028
# Epoch 919/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 920/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0053
# Epoch 921/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0056
# Epoch 922/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 923/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0042
# Epoch 924/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0034
# Epoch 925/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 926/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0040
# Epoch 927/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0039
# Epoch 928/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 929/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0036
# Epoch 930/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0035
# Epoch 931/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0034
# Epoch 932/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0033
# Epoch 933/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 934/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0035
# Epoch 935/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0055
# Epoch 936/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0043
# Epoch 937/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0038
# Epoch 938/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0036
# Epoch 939/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0028
# Epoch 940/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0034
# Epoch 941/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0028
# Epoch 942/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0031
# Epoch 943/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0026
# Epoch 944/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0031
# Epoch 945/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0025
# Epoch 946/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0031
# Epoch 947/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0033
# Epoch 948/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0023
# Epoch 949/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0030
# Epoch 950/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0031
# Epoch 951/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0031
# Epoch 952/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 953/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0026
# Epoch 954/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0029
# Epoch 955/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0030
# Epoch 956/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0023
# Epoch 957/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0039
# Epoch 958/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0043
# Epoch 959/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0040
# Epoch 960/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0042
# Epoch 961/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0032
# Epoch 962/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0039
# Epoch 963/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0026
# Epoch 964/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0030
# Epoch 965/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0022
# Epoch 966/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0030
# Epoch 967/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0033
# Epoch 968/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0031
# Epoch 969/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 970/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0038
# Epoch 971/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0041
# Epoch 972/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0031
# Epoch 973/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0040
# Epoch 974/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0025
# Epoch 975/1000
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0029
# Epoch 976/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0024
# Epoch 977/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0030
# Epoch 978/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0033
# Epoch 979/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0032
# Epoch 980/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0072
# Epoch 981/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0055
# Epoch 982/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0036
# Epoch 983/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0031
# Epoch 984/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0033
# Epoch 985/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0024
# Epoch 986/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0027
# Epoch 987/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0030
# Epoch 988/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0023
# Epoch 989/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0023
# Epoch 990/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0030
# Epoch 991/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0038
# Epoch 992/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0028
# Epoch 993/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0031
# Epoch 994/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 995/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0027
# Epoch 996/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0027
# Epoch 997/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0043
# Epoch 998/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0047
# Epoch 999/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0040
# Epoch 1000/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0037
# 195.9479615688324

# %%
# using last 14 values to predict the next value
test_uber_series_updated = df_uber_final[len(df_uber_final) - len(test_uber_series) - 14:]['UberPickups'].values
test_uber_series_updated = test_uber_series_updated.reshape(-1,1)
test_uber_series_updated = mms.transform(test_uber_series_updated)
test_uber_series_updated[0:10]
# Out:
# array([[0.65726947],
#        [0.72960772],
#        [0.81569131],
#        [0.82318768],
#        [0.68832419],
#        [0.56061254],
#        [0.61345546],
#        [0.66073847],
#        [0.79777604],
#        [0.82472022]])

# %%
## Create properly structured test set:
x_test = []
for rides in range(14,29):
    x_test.append(test_uber_series_updated[rides-14:rides,0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, newshape = (x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (15, 14, 1)

# %%
## Make prediction for test set and bring values back to original scale
pred = lstmmodel.predict(x_test)
pred = mms.inverse_transform(pred)

## Check RMSE on test-set
residuals = pred[0:-1] - test_uber_series
rmse = np.sqrt(np.mean(residuals**2))
rmse
# Out:
# 1/1 [==============================] - 1s 1s/step
# 9763.344874808672

# %% [markdown]
# ### Plot LSTM Predictions

# %%
fig, ax = plt.subplots(figsize = (12,6))

e = [i*0.05 for i in pred]
ax.plot(pred, color = 'red', label = 'Predictions')
#ax.errorbar(x = range(15), y = pred, yerr = e, fmt = '*', color = 'r')
ax.plot(test_uber_series, color = 'black', label = 'True')

ax.set_xlabel('Last two weeks of June 2015', fontsize = 15)
ax.set_ylabel('#Uber-trips', fontsize = 15)
ax.set_title('LSTM Predicted vs Actual Values \n RMSE: {}'.format(np.round(rmse,2)), fontsize = 20)

ax.legend()
plt.show()

# %%
fig ,ax = plt.subplots(figsize = (12,6))
ax.plot(residuals)

ax.set_xlabel('Last two weeks of June-2015', fontsize = 15)
ax.set_ylabel('Error in predictions', fontsize = 15)
ax.set_title('RMSE with Test Data: {}'.format(round(rmse, 3)), fontsize = 20)
plt.show()

# %%
pred_train = lstmmodel.predict(x_train)
pred_train = mms.inverse_transform(pred_train)
residuals_train = pred_train - train_uber_series[0:-14]
rmse_train = np.sqrt(np.mean(residuals_train**2))

fig, ax = plt.subplots(figsize = (16,6))

ax.plot(pred_train, color = 'red', label = 'Predictions')
ax.plot(train_uber_series, color = 'black', label = 'True')

ax.set_xlabel('Time-steps (Jan-June 2015)', fontsize = 15)
ax.set_ylabel('#Uber trips', fontsize = 15)
ax.set_title('Comparing LSTM-predictions with training data \n RMSE: {}'.format(round(rmse_train,3)), fontsize = 20)

ax.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 5ms/step

# %%
#Export prediction results for LSTM
df_pred=pd.DataFrame()
df_pred['Actual_trips']=train_uber_series[0:-14].flatten()
df_pred['Predicted_trips']=pred_train

# %%
df_pred.to_csv('/content/drive/My Drive/ColabNotebooks/IOT/Final Project/Final_Project_LSTM_Prediction.csv', index = None)

# %% [markdown]
# ## LSTM Prediction Analysis
# - From the graph "LSTM predicted VS True Value" we can observe that the predicted values of uber trips followed the actual values of uber trips until 9th day.
# - The predicted values for the 10th day deviated from the actual trip counts. Notably, on the 10th day, the actual trip count surged to 120,000, surpassing the range observed in the previous nine days, which typically fell between 70,000 and 95,000 trips.
# - Predicted vaules on 10th day did not follow actual values of trips as the actual values are higher in number and could be outliers or anomalies.
# - This proves that model is performing well and did not overfit with testing data.
# - RMSE value(Test Data) 9763.345 indicates the average deviation between the predicted values generated by the LSTM model and the actual values in the training data
# - We can see from RMSE with Test Data graph that the peak deviation occured on 10th day with 30,000 trips, rest of the days deviation lies in range of 5000 to -10,000
